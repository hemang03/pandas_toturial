# %% [markdown]
# <a href="https://colab.research.google.com/github/hemang03/pandas_toturial/blob/master/pandas_tutorial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/survey_results_schema.csv')

# %%
df.head(3)
# Out:
#          Column                                           Question
# 0    Respondent                               Respondent ID number
# 1  Professional         Which of the following best describes you?
# 2  ProgramHobby  Do you program as a hobby or contribute to ope...

# %%
df2 = pd.read_csv('/content/survey_results_public.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (13,20,21,22,23,24,25,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2.head(3)
# Out:
#    Respondent            Professional  ...    Salary ExpectedSalary
# 0           1                 Student  ...       NaN            NaN
# 1           2                 Student  ...       NaN        37500.0
# 2           3  Professional developer  ...  113750.0            NaN
#
# [3 rows x 154 columns]

# %%
person ={'first':['hemang' , 'rohan' , 'bhavya' , 'sagar'],
         'last':['patel' , 'nammaik' , 'patel2' , 'mhinde'] , 
         'email ':['hemang@gmail.com' , 'rohan@gmail.com' , 'patel@gmail.com' , 'mhinde@gmail.com']}

# %%
df3 = pd.DataFrame(person)
df3
# Out:
#     first     last            email
# 0  hemang    patel  hemang@gmail.com
# 1   rohan  nammaik   rohan@gmail.com
# 2  bhavya   patel2   patel@gmail.com
# 3   sagar   mhinde  mhinde@gmail.com

# %%
df3['email ']
# Out:
# 0    hemang@gmail.com
# 1     rohan@gmail.com
# 2     patel@gmail.com
# 3    mhinde@gmail.com
# Name: email , dtype: object

# %%
df3.loc[[0,1]]
# Out:
#     first     last            email
# 0  hemang    patel  hemang@gmail.com
# 1   rohan  nammaik   rohan@gmail.com

# %%
df3.columns
# Out:
# Index(['first', 'last', 'email '], dtype='object')

# %%
df3.iloc[[0,1] ,2]
# Out:
# 0    hemang@gmail.com
# 1     rohan@gmail.com
# Name: email , dtype: object

# %%
df3.loc[[0,1], ['last' , 'first']]
# Out:
#       last   first
# 0    patel  hemang
# 1  nammaik   rohan

# %%
df2.shape
# Out:
# (4131, 154)

# %%
df2.columns
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', length=154)

# %%
df2['Salary']
# Out:
# 0            NaN
# 1            NaN
# 2       113750.0
# 3            NaN
# 4            NaN
#           ...
# 4126         NaN
# 4127         NaN
# 4128         NaN
# 4129         NaN
# 4130         NaN
# Name: Salary, Length: 4131, dtype: float64

# %%
df2['ProgramHobby'].value_counts()
# Out:
# Yes, I program as a hobby                    2040
# Yes, both                                    1140
# No                                            712
# Yes, I contribute to open source projects     239
# Name: ProgramHobby, dtype: int64

# %%
df.loc[0]
# Out:
# Column                Respondent
# Question    Respondent ID number
# Name: 0, dtype: object

# %%
df2.loc[0:4 , 'ProgramHobby']
# Out:
# 0                    Yes, both
# 1                    Yes, both
# 2                    Yes, both
# 3                    Yes, both
# 4    Yes, I program as a hobby
# Name: ProgramHobby, dtype: object

# %%
df2.loc[0:14 , 'ProgramHobby' :'StackOverflowMakeMoney']
# Out:
#                  ProgramHobby  ... StackOverflowMakeMoney
# 0                   Yes, both  ...      Strongly disagree
# 1                   Yes, both  ...      Strongly disagree
# 2                   Yes, both  ...               Disagree
# 3                   Yes, both  ...               Disagree
# 4   Yes, I program as a hobby  ...                    NaN
# 5                   Yes, both  ...               Disagree
# 6                   Yes, both  ...               Disagree
# 7                   Yes, both  ...         Somewhat agree
# 8   Yes, I program as a hobby  ...      Strongly disagree
# 9   Yes, I program as a hobby  ...               Disagree
# 10  Yes, I program as a hobby  ...      Strongly disagree
# 11                         No  ...                    NaN
# 12  Yes, I program as a hobby  ...      Strongly disagree
# 13                  Yes, both  ...               Disagree
# 14  Yes, I program as a hobby  ...               Disagree
#
# [15 rows x 143 columns]

# %%
df2.iloc[0:3 , 12:19]
# Out:
#       YearsCodedJob YearsCodedJobPast  ... NonDeveloperType CareerSatisfaction
# 0               NaN               NaN  ...              NaN                NaN
# 1               NaN               NaN  ...              NaN                NaN
# 2  20 or more years               NaN  ...              NaN                8.0
#
# [3 rows x 7 columns]

# %%
# thank you for seeing
